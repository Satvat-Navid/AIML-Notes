# %% [markdown]
# **Some basic methods of pandas**

# %%
import pandas as pd
import numpy as np

# %%
m = np.array(range(2, 27, 3)).reshape(3, 3)

# %%
np.random.shuffle(m)

# %%
m
# Out:
# array([[ 2,  5,  8],
#        [11, 14, 17],
#        [20, 23, 26]])

# %%
df = pd.DataFrame(m)

# %%
df
# Out:
#     0   1   2
# 0   2   5   8
# 1  11  14  17
# 2  20  23  26

# %%
df.set_index(pd.Series([1, 2, 3]))
# Out:
#     0   1   2
# 1   2   5   8
# 2  11  14  17
# 3  20  23  26

# %%
mtx = np.random.rand(30, 30)

# %%
df1 = pd.DataFrame(mtx)

# %%
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.642545  0.279010  0.961061  0.420411  0.884218  0.458899  0.557536
# 1  0.226287  0.852515  0.378313  0.503174  0.955168  0.642676  0.778044
# 2  0.916522  0.938149  0.148479  0.329797  0.823535  0.617220  0.208724
# 3  0.825914  0.124949  0.885235  0.146639  0.434887  0.185285  0.643024
# 4  0.114847  0.300297  0.977836  0.465591  0.574372  0.400772  0.662858
#
#          7         8         9   ...        20        21        22        23  \
# 0  0.765870  0.832874  0.558719  ...  0.519346  0.344084  0.855906  0.070178
# 1  0.752021  0.280504  0.750562  ...  0.240730  0.280841  0.772411  0.758372
# 2  0.762389  0.359349  0.033689  ...  0.963217  0.717979  0.390010  0.560366
# 3  0.699937  0.496408  0.519753  ...  0.535063  0.557098  0.925028  0.864472
# 4  0.799221  0.493761  0.326790  ...  0.887829  0.765595  0.494317  0.075255
#
#          24        25        26        27        28        29
# ...

# %%
df1 = df1.drop(columns=[0], index=[0])

# %%
df1
# Out:
#           1         2         3         4         5         6         7   \
# 1   0.852515  0.378313  0.503174  0.955168  0.642676  0.778044  0.752021
# 2   0.938149  0.148479  0.329797  0.823535  0.617220  0.208724  0.762389
# 3   0.124949  0.885235  0.146639  0.434887  0.185285  0.643024  0.699937
# 4   0.300297  0.977836  0.465591  0.574372  0.400772  0.662858  0.799221
# 5   0.866644  0.679751  0.638787  0.581328  0.051803  0.318622  0.546272
# 6   0.031192  0.861282  0.637595  0.782748  0.508181  0.879967  0.662149
# 7   0.976374  0.448794  0.632374  0.386868  0.311077  0.312413  0.029473
# 8   0.921007  0.823726  0.535683  0.129308  0.152481  0.545863  0.800160
# 9   0.339829  0.070034  0.904840  0.189443  0.838672  0.812931  0.623281
# 10  0.368539  0.540831  0.947631  0.595755  0.338727  0.881257  0.023616
# 11  0.308648  0.575524  0.485942  0.106194  0.884582  0.599335  0.006672
# 12  0.529084  0.119816  0.520455  0.801704  0.963943  0.101054  0.703386
# ...

# %%
df1.describe()
# Out:
#               1          2          3          4          5          6   \
# count  29.000000  29.000000  29.000000  29.000000  29.000000  29.000000
# mean    0.542707   0.510325   0.520620   0.488358   0.432260   0.647046
# std     0.318785   0.361678   0.260326   0.267334   0.288806   0.262390
# min     0.031192   0.060791   0.057766   0.097631   0.051803   0.101054
# 25%     0.300297   0.145445   0.329797   0.222533   0.189736   0.484664
# 50%     0.529084   0.540831   0.520455   0.484214   0.338727   0.643024
# 75%     0.866644   0.861282   0.712215   0.717379   0.642676   0.879967
# max     0.996293   0.979835   0.947631   0.955168   0.963943   0.998736
#
#               7          8          9          10  ...         20         21  \
# count  29.000000  29.000000  29.000000  29.000000  ...  29.000000  29.000000
# mean    0.582350   0.491863   0.425719   0.497328  ...   0.539839   0.439155
# std     0.311645   0.283150   0.281931   0.328798  ...   0.301033   0.282109
# ...

# %%
df1 = df1.drop(pd.Series(np.arange(4, 30)), axis=True)
df1.columns = list("ABC")
df1.tail()
# Out:
#            A         B         C
# 25  0.553267  0.955674  0.329727
# 26  0.123209  0.060791  0.804543
# 27  0.490441  0.070887  0.704777
# 28  0.242259  0.163784  0.151211
# 29  0.952651  0.067548  0.352019

# %%
df1.insert(3, 'D', np.random.rand(29))

# %%
df1.tail(4)
# Out:
#            A         B         C         D
# 26  0.123209  0.060791  0.804543  0.456901
# 27  0.490441  0.070887  0.704777  0.886278
# 28  0.242259  0.163784  0.151211  0.655306
# 29  0.952651  0.067548  0.352019  0.336616

# %%
df1.iloc[28] = np.random.rand(4)

# %%
df1.tail(4)
# Out:
#            A         B         C         D
# 26  0.123209  0.060791  0.804543  0.456901
# 27  0.490441  0.070887  0.704777  0.886278
# 28  0.242259  0.163784  0.151211  0.655306
# 29  0.624269  0.150278  0.214315  0.671899

# %%
newR = np.random.rand(4)
newR
# Out:
# array([0.71480697, 0.24551813, 0.99318527, 0.61724612])

# %%
df1.loc[30] = newR
df1.tail()
# Out:
#            A         B         C         D
# 26  0.123209  0.060791  0.804543  0.456901
# 27  0.490441  0.070887  0.704777  0.886278
# 28  0.242259  0.163784  0.151211  0.655306
# 29  0.624269  0.150278  0.214315  0.671899
# 30  0.714807  0.245518  0.993185  0.617246

# %%
df1 = df1.drop(np.arange(5, 31))
df1
# Out:
#           A         B         C         D
# 1  0.852515  0.378313  0.503174  0.519155
# 2  0.938149  0.148479  0.329797  0.986823
# 3  0.124949  0.885235  0.146639  0.743161
# 4  0.300297  0.977836  0.465591  0.598207

# %%
df1.loc[:,'A']
# Out:
# 1    0.852515
# 2    0.938149
# 3    0.124949
# 4    0.300297
# Name: A, dtype: float64

# %%
df1.A
# Out:
# 1    0.852515
# 2    0.938149
# 3    0.124949
# 4    0.300297
# Name: A, dtype: float64

# %%
df1.loc[1]  # First row
# Out:
# A    0.852515
# B    0.378313
# C    0.503174
# D    0.519155
# Name: 1, dtype: float64
